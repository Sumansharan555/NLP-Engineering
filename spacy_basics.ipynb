# %%
# Import spapCy and load the language library
import spacy
nlp = spacy.load('en_core_web_sm')

# create a Doc object
doc = nlp(u"Tesla is looking at buying U.S. startup for $6 million")

# print each token separatly
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB advcl
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %% [markdown]
# Tokenisation

# %%
doc2 = nlp(u"Tesla isn't   looking into startups anymore.")

for token in doc2:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#    SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2
# Out:
# Tesla isn't   looking into startups anymore.

# %%
doc2[0]
# Out:
# Tesla

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
# dependency
doc2[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain("nsubj")
# Out:
# 'nominal subject'

# %%
spacy.explain("PROPN")
# Out:
# 'proper noun'

# %%
# lemmas(the base form of word):
print(doc2[4].text)
print(doc2[4].lemma_)
# Out:
# looking
# look

# %%
# simple parts-of speech & detailed tags:
print(doc2[4].pos_)
print(doc2[4].tag_ + '/' + spacy.explain(doc2[4].tag_))
# Out:
# VERB
# VBG/verb, gerund or present participle

# %%
# simple parts-of speech & detailed tags:
print(doc2[4].pos_)
print(doc2[4].tag_  spacy.explain(doc2[4].tag_))
# Out:
#   File "/tmp/ipython-input-1067913716.py", line 3
#     print(doc2[4].tag_  spacy.explain(doc2[4].tag_))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# word shapes:
print(doc2[0].text+': '+doc2[0].shape_)
print(doc[5].text+' : '+doc[5].shape_)
# Out:
# Tesla: Xxxxx
# U.S. : X.X.

# %%
# word shapes
print(doc2[0].is_alpha)
print(doc[5].is_alpha)
print(doc[5].is_stop)
# Out:
# True
# False
# False

# %%
doc2[0]
# Out:
# Tesla

# %%
doc[5]
# Out:
# U.S.

# %% [markdown]
# Spans

# %% [markdown]
# Although commonly atributed to John Lennon from his song "Beautiful Boy",\the phrase "Life is what happens to us while we are making other plans" was written by \cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.

# %%
doc3 = nlp('Although commonly atributed to John Lennon from his song "Beautiful Boy",\the phrase "Life is what happens to us while we are making other plans" was written by \cartoonist Allen Saunders and published in Readers Digest in 1957, when Lennon was 17.')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipython-input-3458128611.py:1: SyntaxWarning: invalid escape sequence '\c'
#   doc3 = nlp('Although commonly atributed to John Lennon from his song "Beautiful Boy",\the phrase "Life is what happens to us while we are making other plans" was written by \cartoonist Allen Saunders and published in Readers Digest in 1957, when Lennon was 17.')

# %%
life_quote = doc3[16:30]
print(life_quote)
# Out:
# phrase "Life is what happens to us while we are making other plans

# %% [markdown]
# This is the first sentence. This is another sentence. This is the last sentence.

# %%
doc4 = nlp(u'This is the first sentence. This is another sentence. This is the last sentence.')

# %%
for sent in doc4.sents:
    print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence.

# %%
doc4[6].is_sent_start
# Out:
# True
