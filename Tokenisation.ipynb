# %% [markdown]
# Tokenisation using spacy

# %%
# Import spaCy and load the language library
import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object

# %%
# create a string that includews opening and closing quotation marks
mystring = '"We\'re moving to L.A.!"'
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
# create a doc object and explore tokens
doc = nlp(mystring)
for token in doc:
    print(token.text, end=' | ')
# Out:
# " | We | 're | moving | to | L.A. | ! | " |

# %% [markdown]
# Prefixes, Suffixes and Infixes

# %% [markdown]
# we're here to help! Send snail-email, email support@oursite.com or visit us at http://www.oursite.com!

# %%
doc2 = nlp(u"We're here to help! Send snail-email, email support@oursite.com or visit us at http://www.oursite.com!")
for t in doc2:
    print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# email
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3 = nlp(u'A 5km NYC cab ride costs $10.30')
for t in doc3:
    print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %% [markdown]
# Exceptions

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

for t in doc4:
    print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %% [markdown]
# Counting Tokens

# %%
len(doc)
# Out:
# 8

# %% [markdown]
# Counting vocab Entries

# %%
len(doc.vocab)
# Out:
# 794

# %% [markdown]
# TOkens can be rretrieved by index position and slice

# %%
doc5 = nlp(u'It is better to give than to receive.')

# Retrieve the third token:
doc5[2]
# Out:
# better

# %%
# retrieve 3 tokens fom the middle
doc5[2:5]
# Out:
# better to give

# %%
# retrieve from the last
doc5[-4]
# Out:
# than

# %%
# retrieve the last four tokens
doc5[-4:]
# Out:
# than to receive.

# %% [markdown]
# Tokens can't be reassigned

# %%
doc6 = nlp(u"My dinner was horrible.")
doc7 = nlp(u"Your dinner was delicious.")

# %%
# Try to change "My dinner was horrible" to "My dinner was delicious"
doc6[3] = doc7[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3136367382.py in <cell line: 0>()
#       1 # Try to change "My dinner was horrible" to "My dinner was delicious"
# ----> 2 doc6[3] = doc7[3]
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %% [markdown]
# Named Entities

# %%
doc8 = nlp(u"Apple to build a Hong Kong factory for $6 million")

for token in doc8:
    print(token.text, end=' | ')
print("\n----")
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |
# ----

# %%
for ent in doc8.ents:
    print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
# Out:
# Apple - ORG - Companies, agencies, institutions, etc.
# Hong Kong - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %%
len(doc8.ents)
# Out:
# 3

# %% [markdown]
# Noun Chunks

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
doc10 = nlp(u"Red cars do not carry higher insurence rates.")
for chunk in doc10.noun_chunks:
    print(chunk.text)
# Out:
# Red cars
# higher insurence rates

# %%
doc11 = nlp(u"He was a one-eyed, one-horned, flying, purple people-eater.")
for chunk in doc11.noun_chunks:
    print(chunk.text)
# Out:
# He
# a one-eyed, one-horned, flying, purple people-eater

# %% [markdown]
# Build-in visualiser

# %% [markdown]
# Visualising the dependency parse

# %%
from spacy import displacy

doc = nlp(u"Apple is going to build a U.K. factory for $6 million.")
displacy.render(doc, style='dep', jupyter=True, options={'distance': 80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="22e8e43057174c19b6296b58dca2f98c-0" class="displacy" width="1010" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-0" stroke-width="2px" d="M70,162.0 C70,82.0 200.0,82.0 200.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,164.0 L62,152.0 78,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-1" stroke-width="2px" d="M150,162.0 C150,122.0 195.0,122.0 195.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,164.0 L142,152.0 158,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-2" stroke-width="2px" d="M310,162.0 C310,122.0 355.0,122.0 355.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,164.0 L302,152.0 318,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-3" stroke-width="2px" d="M230,162.0 C230,82.0 360.0,82.0 360.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M360.0,164.0 L368.0,152.0 352.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-4" stroke-width="2px" d="M470,162.0 C470,82.0 600.0,82.0 600.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,164.0 L462,152.0 478,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-5" stroke-width="2px" d="M550,162.0 C550,122.0 595.0,122.0 595.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,164.0 L542,152.0 558,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-6" stroke-width="2px" d="M390,162.0 C390,42.0 605.0,42.0 605.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M605.0,164.0 L613.0,152.0 597.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b6296b58dca2f98c-0-7" stroke-width="2px" d="M390,162.0 C390,2.0 690.0,2.0 690.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22e8e43057174c19b6296b58dca2f98c-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M690.0,164.0 L698.0,152.0 682.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22e8e43057174c19b629

# %%
doc = nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.")
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  iPods for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %%
doc = nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.")
displacy.render(doc, style='ent', jupyter=False)
# Out:
# '<div class="entities" style="line-height: 2.5; direction: ltr">Over \n<mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    the last quarter\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>\n</mark>\n \n<mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Apple\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>\n</mark>\n sold \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    nearly 20 thousand\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>\n</mark>\n iPods for a profit of \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    $6 million\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>\n</mark>\n.</div>'
